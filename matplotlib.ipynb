# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,200)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y = np.sin(x)

# %%
y
# Out:
# array([0.24500414, 0.81958747, 0.69599121, 0.71231204, 0.08175513,
#        0.40221078, 0.54726482, 0.84023188, 0.26436665, 0.14123677,
#        0.11672884, 0.21917838, 0.05636262, 0.73527249, 0.78758385,
#        0.27216362, 0.06046682, 0.358315  , 0.14081977, 0.22577798,
#        0.11305282, 0.33329248, 0.8092035 , 0.12965128, 0.6361413 ,
#        0.51800292, 0.68730949, 0.71294438, 0.49170794, 0.55726607,
#        0.14208448, 0.3675693 , 0.77823793, 0.79928878, 0.75086418,
#        0.35914968, 0.06712837, 0.3098046 , 0.83983131, 0.68547943,
#        0.13390026, 0.02915616, 0.43286018, 0.47666416, 0.42357653,
#        0.36457245, 0.43605311, 0.278175  , 0.26028355, 0.01113516])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, '--b')
plt.figure(figsize=(8,4))
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is my title")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)

# %%
x
# Out:
# array([0.03181412, 0.67950983, 0.24772192, 0.34255075, 0.97724676,
#        0.75159085, 0.42156332, 0.05022728, 0.18601583, 0.90771484,
#        0.31097106, 0.84782948, 0.61935177, 0.12544214, 0.37001346,
#        0.42304454, 0.73425331, 0.49505167, 0.98471352, 0.51559142,
#        0.18422005, 0.55256711, 0.25307448, 0.99046697, 0.71521944,
#        0.59103911, 0.01718862, 0.07752464, 0.20277304, 0.67872521,
#        0.33602798, 0.85287969, 0.21034315, 0.13701362, 0.37885301,
#        0.60079592, 0.13284314, 0.74194775, 0.5318006 , 0.41672034,
#        0.37246662, 0.94996284, 0.52022146, 0.13221095, 0.56715292,
#        0.98654776, 0.14929113, 0.82568909, 0.6492068 , 0.48450076])

# %%
y
# Out:
# array([0.39885848, 0.94685767, 0.85779363, 0.49835257, 0.07505176,
#        0.20427653, 0.78824011, 0.6868926 , 0.19889508, 0.09090186,
#        0.46299648, 0.12673674, 0.06083983, 0.18539394, 0.78011065,
#        0.91684947, 0.44182529, 0.08696611, 0.34491722, 0.58590185,
#        0.96791973, 0.11837396, 0.84062305, 0.95230273, 0.73397284,
#        0.4902947 , 0.96346472, 0.64634998, 0.64028532, 0.99875448,
#        0.21784223, 0.33041465, 0.5354071 , 0.68278988, 0.35919717,
#        0.63763423, 0.19609511, 0.83934964, 0.75603768, 0.0591507 ,
#        0.08175292, 0.54884402, 0.35350301, 0.53688957, 0.90833132,
#        0.03264525, 0.74909058, 0.49443226, 0.46874498, 0.49756376])

# %%
colours = np.random.rand(50)
sizes = 500 *np.random.rand(50)
plt.scatter(x,y, c= colours , s = sizes, alpha = .8)
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
x = ['a','b','c','d','e']

# %%
y = np.random.rand(5)
plt.bar(x,y)
plt.xlabel("x axis")
# Out:
# Text(0.5, 0, 'x axis')

# %%
y
# Out:
# array([0.9703976 , 0.55733495, 0.68979203, 0.24886349, 0.20423359])

# %%
plt.barh(x,y)
plt.bar(x,y)
plt.xlabel("x axis")
# Out:
# Text(0.5, 0, 'x axis')

# %%
x = [4,5,6,7,8,9]
y = [6,7,8,9,10,11]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,70,80,19,40,11]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,70,80,19,40,11]
plt.scatter(x,y)
plt.show()

# %%
data = [1,2,3,4,5,6,1,2,3,7,8]

# %%
plt.hist(data)
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
plt.show()
